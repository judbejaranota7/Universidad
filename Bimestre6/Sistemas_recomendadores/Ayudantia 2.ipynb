# %% [markdown]
# # Ayudantía 2
#
# Repositorio de tutoriales y material externo
#
# MAN 3160 - Sistemas Recomendadores

# %% [markdown]
# # Semana 1 - No personalizada, IKNN, UKNN, slope-one (Surprise)

# %% [markdown]
# * [Building Recommender System with Surprise [IKNN, UKNN, slope-one, FunkSVD]](https://colab.research.google.com/github/singhsidhukuldeep/Recommendation-System/blob/master/Building_Recommender_System_with_Surprise.ipynb#scrollTo=K-yPIqzzt5et) Recomendación de películas y comparación de rendimiento de métodos.
# * [Using Scikit-Surprise to Create a Simple Recipe Collaborative Filtering Recommender System.](https://www.alldatascience.com/recommender-systems/simple-recipe-recommender-system-with-scikit-surprise/) Recomendación de recetas (de cocina) en base a ratings con KNN y SVD
# * [Documentación Surpriselib](https://surprise.readthedocs.io/en/stable/getting_started.html)

# %% [markdown]
# # Semana 2 - Recomendación basada en contenido y Factorización Matricial

# %% [markdown]
# * [Hands-on Content Based Recommender System using Python](https://towardsdatascience.com/hands-on-content-based-recommender-system-using-python-1d643bf314e4) Recomendación de películas en base a similaridad según vectores latentes de su sinopsis.
# * [Beginner Tutorial: Recommender Systems in Python](https://www.datacamp.com/tutorial/recommender-systems-python). Recomendación de películas por método no personalizado y luego según vectorización de título y meta-data adicional.
# * [Basic content-based recommendation system with Python code](https://medium.com/mlearning-ai/basic-content-based-recommendation-system-with-python-code-be920b412067) Recomendación de películas y series según descripción verbal.
# * [Recomendación basada en contenido visual para recomendación de arte](https://github.com/PUC-RecSys-Class/RecSysPUC-2022/blob/master/practicos/Content_Based_imagenes.ipynb)

# %% [markdown]
# # Semana 3 y 4 - ALS y BPR (Implicit)

# %% [markdown]
# * [Documentación de Implicit](https://benfred.github.io/implicit/)
# * [ALS Implicit Collaborative Filtering](https://medium.com/radon-dev/als-implicit-collaborative-filtering-5ed653ba39fe) Programación de algoritmo ALS sin utilizar una librería externa para recomendación de música
# * [Ejemplos oficiales de librería Implicit](https://github.com/benfred/implicit/tree/main/examples) Ejemplos de librería Implicit para recomendación en datasets de MovieLens y Last.fm
# * [Alternating Least Square for Implicit Dataset with code](https://towardsdatascience.com/alternating-least-square-for-implicit-dataset-with-code-8e7999277f4b) Tutorial para uso de librería Implicit para la construcción de un recomendador ALS para música.

# %% [markdown]
# # Semana 5 - Recomendadores híbridos y Ensambles

# %% [markdown]
# * [Learning to Rank for Product Recommendations](https://towardsdatascience.com/learning-to-rank-for-product-recommendations-a113221ad8a7) Utilización de algoritmo XGBoost (de ensamble) para recomendar productos.
# * [Implementación de Belkor's Pragmatic Chaos](https://github.com/dandxy89/BellkorAlgorithm/blob/master/resources/Demo.ipynb)
# * [Implementación de BGBDT en Python](https://towardsdatascience.com/gradient-boosted-decision-trees-explained-with-a-real-life-example-and-some-python-code-77cee4ccf5e)
